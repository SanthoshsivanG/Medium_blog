# %%
import pandas as pd   

path = "./marks_dataset/score_updated.csv"
df = pd.read_csv(path)

# Check dataset
print(df.head())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.shape
# Out:
# (96, 2)

# %%
import matplotlib.pyplot as plt 

plt.scatter(df['Hours'], df['Scores'], color='blue')
plt.xlabel("Study Hours")
plt.ylabel("Scores")
plt.title("Study Hours vs Scores")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df[['Hours']]  # Independent variable
y = df['Scores']   # Dependent variable

X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.8, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression 

model = LinearRegression()
model.fit(X_train, y_train)

# Get model parameters
print(f"Intercept: {model.intercept_}")
print(f"Coefficient: {model.coef_[0]}")
# Out:
# Intercept: 1.5655135906842688
# Coefficient: 9.945997462181808

# %%
y_pred = model.predict(X_test)

# Comparing actual vs predicted values
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results)
# Out:
#     Actual  Predicted
# 26      90  96.052489
# 84      40  41.349503
# 2       27  33.392705
# 55      48  47.317102
# 68      74  69.198296
# 81      72  73.176695
# 16      30  26.430507
# 78      57  57.263099
# 54      26  25.435907
# 66      15  15.489910
# 53      36  37.371104
# 88      34  31.403506
# 71      65  66.214497
# 13      42  34.387305
# 7       60  56.268500
# 30      19  17.479110
# 22      35  39.360304
# 24      86  79.144294
# 33      82  82.128093
# 8       81  84.117293

# %%
# Set bar width
bar_width = 0.35
index = np.arange(len(results))

# Plotting side-by-side bars for actual vs predicted values
plt.figure(figsize=(14, 6))

# Actual bars
plt.bar(index, results['Actual'], bar_width, label='Actual', color='blue', alpha=0.6)

# Predicted bars (shifted by bar_width)
plt.bar(index + bar_width, results['Predicted'], bar_width, label='Predicted', color='orange', alpha=0.6)

# Adding titles and labels
plt.title('Actual vs Predicted Values')
plt.xlabel('Index')
plt.ylabel('Values')

# Adding the x-axis labels (index)
plt.xticks(index + bar_width / 2, np.arange(1, len(results) + 1))

# Show legend
plt.legend()

# Display plot
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 13.881520927483525

# %%
plt.scatter(X_test, y_test, color='blue', label="Actual Data")
plt.plot(X_test, y_pred, color='red', linewidth=2, label="Regression Line")
plt.xlabel("Size (sq ft)")
plt.ylabel("Price ($1000s)")
plt.legend()
plt.title("Linear Regression Model")
plt.show()
